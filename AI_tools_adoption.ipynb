# %%
import pandas as pd

df = pd.read_csv('/content/AI Tools Adoption.csv')
display(df.head())
# Out:
#    record_id  user_id     role education_level      subject_area  \
# 0          1  S439563  student        graduate           Physics
# 1          2  S229815  student        graduate         Sociology
# 2          3  S698951  student   undergraduate         Chemistry
# 3          4  S414834  student   undergraduate               Law
# 4          5  S708064  student   undergraduate  Computer Science
#
#           ai_tool        ai_use_purpose  ai_use_frequency_per_week  \
# 0   LLM Assistant         summarization                          5
# 1  Concept Mapper         brainstorming                          3
# 2        AI Tutor     note organization                          0
# 3  Quiz Generator  language translation                          3
# 4        AI Tutor   concept explanation                          2
#
#    session_count  avg_session_duration_min  ...  recommended_resources_count  \
# 0             22                        18  ...                            8
# 1             27                         8  ...                            5
# 2             21                        10  ...                            4
# 3             26                        19  ...                            5
# 4             17                        26  ...                            9
#
#    perceived_usefulness perceived_ease_of_use trust_score  adoption_intention  \
# 0                     2                     3           3                   2
# 1                     1                     4           3                   2
# 2                     2                     2           3                   5
# 3                     2                     4           5                   4
# 4                     4                     2           4                   5
#
#    satisfaction_score ethical_concern_privacy  ethical_concern_plagiarism  \
# 0                   2                       3                           5
# 1                   4                       2                           4
# 2                   3                       3                           5
# 3                   3                       2                           2
# 4                   4                       2                           3
#
#    dropout_flag         timestamp
# 0             0     2/8/2023 2:56
# 1             0    5/17/2023 9:53
# 2             0  11/18/2023 15:53
# 3             0    6/5/2023 16:41
# 4             0     4/1/2024 9:42
#
# [5 rows x 32 columns]

# %%
df.shape
# Out:
# (50000, 32)

# %%
df.head()
# Out:
#    record_id  user_id     role education_level      subject_area  \
# 0          1  S439563  student        graduate           Physics
# 1          2  S229815  student        graduate         Sociology
# 2          3  S698951  student   undergraduate         Chemistry
# 3          4  S414834  student   undergraduate               Law
# 4          5  S708064  student   undergraduate  Computer Science
#
#           ai_tool        ai_use_purpose  ai_use_frequency_per_week  \
# 0   LLM Assistant         summarization                          5
# 1  Concept Mapper         brainstorming                          3
# 2        AI Tutor     note organization                          0
# 3  Quiz Generator  language translation                          3
# 4        AI Tutor   concept explanation                          2
#
#    session_count  avg_session_duration_min  ...  recommended_resources_count  \
# 0             22                        18  ...                            8
# 1             27                         8  ...                            5
# 2             21                        10  ...                            4
# 3             26                        19  ...                            5
# 4             17                        26  ...                            9
#
#    perceived_usefulness perceived_ease_of_use trust_score  adoption_intention  \
# 0                     2                     3           3                   2
# 1                     1                     4           3                   2
# 2                     2                     2           3                   5
# 3                     2                     4           5                   4
# 4                     4                     2           4                   5
#
#    satisfaction_score ethical_concern_privacy  ethical_concern_plagiarism  \
# 0                   2                       3                           5
# 1                   4                       2                           4
# 2                   3                       3                           5
# 3                   3                       2                           2
# 4                   4                       2                           3
#
#    dropout_flag         timestamp
# 0             0     2/8/2023 2:56
# 1             0    5/17/2023 9:53
# 2             0  11/18/2023 15:53
# 3             0    6/5/2023 16:41
# 4             0     4/1/2024 9:42
#
# [5 rows x 32 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   record_id                    50000 non-null  int64
#  1   user_id                      50000 non-null  object
#  2   role                         50000 non-null  object
#  3   education_level              50000 non-null  object
#  4   subject_area                 50000 non-null  object
#  5   ai_tool                      50000 non-null  object
#  6   ai_use_purpose               50000 non-null  object
#  7   ai_use_frequency_per_week    50000 non-null  int64
#  8   session_count                50000 non-null  int64
#  9   avg_session_duration_min     50000 non-null  int64
#  10  tasks_completed              50000 non-null  int64
#  11  hints_requested              50000 non-null  int64
#  12  text_feedback                50000 non-null  object
#  13  sentiment_label              50000 non-null  object
#  14  sentiment_polarity           50000 non-null  float64
#  15  subjectivity                 50000 non-null  float64
#  16  emotion_primary              50000 non-null  object
#  17  pre_test_score               50000 non-null  int64
#  18  post_test_score              50000 non-null  int64
#  19  improvement                  50000 non-null  int64
#  20  adaptive_difficulty_start    50000 non-null  int64
#  21  adaptive_difficulty_end      50000 non-null  int64
#  22  recommended_resources_count  50000 non-null  int64
#  23  perceived_usefulness         50000 non-null  int64
#  24  perceived_ease_of_use        50000 non-null  int64
#  25  trust_score                  50000 non-null  int64
#  26  adoption_intention           50000 non-null  int64
#  27  satisfaction_score           50000 non-null  int64
#  28  ethical_concern_privacy      50000 non-null  int64
#  29  ethical_concern_plagiarism   50000 non-null  int64
#  30  dropout_flag                 50000 non-null  int64
#  31  timestamp                    50000 non-null  object
# dtypes: float64(2), int64(20), object(10)
# memory usage: 12.2+ MB

# %% [markdown]
# # New Section

# %%
df.columns
# Out:
# Index(['record_id', 'user_id', 'role', 'education_level', 'subject_area',
#        'ai_tool', 'ai_use_purpose', 'ai_use_frequency_per_week',
#        'session_count', 'avg_session_duration_min', 'tasks_completed',
#        'hints_requested', 'text_feedback', 'sentiment_label',
#        'sentiment_polarity', 'subjectivity', 'emotion_primary',
#        'pre_test_score', 'post_test_score', 'improvement',
#        'adaptive_difficulty_start', 'adaptive_difficulty_end',
#        'recommended_resources_count', 'perceived_usefulness',
#        'perceived_ease_of_use', 'trust_score', 'adoption_intention',
#        'satisfaction_score', 'ethical_concern_privacy',
#        'ethical_concern_plagiarism', 'dropout_flag', 'timestamp'],
#       dtype='object')

# %%
df.describe()
# Out:
#           record_id  ai_use_frequency_per_week  session_count  \
# count  50000.000000               50000.000000   50000.000000
# mean   25000.500000                   2.032660      20.498980
# std    14433.901067                   1.277163       8.573265
# min        1.000000                   0.000000       1.000000
# 25%    12500.750000                   1.000000      14.000000
# 50%    25000.500000                   2.000000      20.000000
# 75%    37500.250000                   3.000000      27.000000
# max    50000.000000                   8.000000      51.000000
#
#        avg_session_duration_min  tasks_completed  hints_requested  \
# count              50000.000000     50000.000000     50000.000000
# mean                  15.562240        46.617040         6.154900
# std                    6.163321        19.842233         3.990166
# min                    3.000000         1.000000         0.000000
# 25%                   11.000000        33.000000         3.000000
# 50%                   16.000000        46.000000         6.000000
# 75%                   20.000000        60.000000         9.000000
# max                   41.000000       134.000000        24.000000
#
#        sentiment_polarity  subjectivity  pre_test_score  post_test_score  ...  \
# count        50000.000000  50000.000000    50000.000000     50000.000000  ...
# mean             0.202119      0.614831       68.404000        76.126520  ...
# std              0.494040      0.173278       14.047923        14.931484  ...
# min             -0.950000      0.200000        5.000000         4.000000  ...
# 25%             -0.060000      0.493000       59.000000        66.000000  ...
# 50%              0.269000      0.617000       68.000000        77.000000  ...
# 75%              0.611000      0.752000       78.000000        87.000000  ...
# max              0.950000      0.950000      100.000000       100.000000  ...
#
#        adaptive_difficulty_end  recommended_resources_count  \
# count              50000.00000                 50000.000000
# mean                   2.69912                     5.552640
# std                    1.02630                     3.062041
# min                    1.00000                     0.000000
# 25%                    2.00000                     3.000000
# 50%                    3.00000                     5.000000
# 75%                    3.00000                     8.000000
# max                    5.00000                    20.000000
#
#        perceived_usefulness  perceived_ease_of_use   trust_score  \
# count          50000.000000           50000.000000  50000.000000
# mean               3.543320               3.479000      3.384200
# std                1.056156               1.000289      1.012705
# min                1.000000               1.000000      1.000000
# 25%                3.000000               3.000000      3.000000
# 50%                4.000000               4.000000      3.000000
# 75%                4.000000               4.000000      4.000000
# max                5.000000               5.000000      5.000000
#
#        adoption_intention  satisfaction_score  ethical_concern_privacy  \
# count        50000.000000        50000.000000             50000.000000
# mean             3.457260            3.423600                 3.017140
# std              1.064235            1.071702                 1.053066
# min              1.000000            1.000000                 1.000000
# 25%              3.000000            3.000000                 2.000000
# 50%              4.000000            3.000000                 3.000000
# 75%              4.000000            4.000000                 4.000000
# max              5.000000            5.000000                 5.000000
#
#        ethical_concern_plagiarism  dropout_flag
# count                50000.000000  50000.000000
# mean                     3.122320      0.047260
# std                      1.049009      0.212197
# min                      1.000000      0.000000
# 25%                      2.000000      0.000000
# 50%                      3.000000      0.000000
# 75%                      4.000000      0.000000
# max                      5.000000      1.000000
#
# [8 rows x 22 columns]

# %%
df.isnull().sum()
# Out:
# record_id                      0
# user_id                        0
# role                           0
# education_level                0
# subject_area                   0
# ai_tool                        0
# ai_use_purpose                 0
# ai_use_frequency_per_week      0
# session_count                  0
# avg_session_duration_min       0
# tasks_completed                0
# hints_requested                0
# text_feedback                  0
# sentiment_label                0
# sentiment_polarity             0
# subjectivity                   0
# emotion_primary                0
# pre_test_score                 0
# post_test_score                0
# improvement                    0
# adaptive_difficulty_start      0
# adaptive_difficulty_end        0
# recommended_resources_count    0
# perceived_usefulness           0
# perceived_ease_of_use          0
# trust_score                    0
# adoption_intention             0
# satisfaction_score             0
# ethical_concern_privacy        0
# ethical_concern_plagiarism     0
# dropout_flag                   0
# timestamp                      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.dtypes
# Out:
# record_id                        int64
# user_id                         object
# role                            object
# education_level                 object
# subject_area                    object
# ai_tool                         object
# ai_use_purpose                  object
# ai_use_frequency_per_week        int64
# session_count                    int64
# avg_session_duration_min         int64
# tasks_completed                  int64
# hints_requested                  int64
# text_feedback                   object
# sentiment_label                 object
# sentiment_polarity             float64
# subjectivity                   float64
# emotion_primary                 object
# pre_test_score                   int64
# post_test_score                  int64
# improvement                      int64
# adaptive_difficulty_start        int64
# adaptive_difficulty_end          int64
# recommended_resources_count      int64
# perceived_usefulness             int64
# perceived_ease_of_use            int64
# trust_score                      int64
# adoption_intention               int64
# satisfaction_score               int64
# ethical_concern_privacy          int64
# ethical_concern_plagiarism       int64
# dropout_flag                     int64
# timestamp                       object
# dtype: object

# %%
df["adoption_intention"].value_counts()
# Out:
# adoption_intention
# 4    16138
# 3    15524
# 5     8983
# 2     7469
# 1     1886
# Name: count, dtype: int64

# %%
df["adoption_intention"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='adoption_intention'>

# %%
df["ai_tool"].value_counts()
# Out:
# ai_tool
# Quiz Generator          5143
# Assessment Assistant    5107
# Explainability Bot      5085
# Code Copilot            5046
# Curriculum Planner      5001
# Speech Coach            4946
# Concept Mapper          4941
# AI Tutor                4929
# AI Writing Helper       4904
# LLM Assistant           4898
# Name: count, dtype: int64

# %%
df["role"].value_counts()
# Out:
# role
# student    25000
# teacher    25000
# Name: count, dtype: int64

# %%
df["education_level"].value_counts()
# Out:
# education_level
# K-12                        14996
# undergraduate               14938
# graduate                    11258
# professional-development     8808
# Name: count, dtype: int64

# %%
df["subject_area"].value_counts()
# Out:
# subject_area
# Engineering         3405
# Law                 3391
# Psychology          3389
# Biology             3373
# Education           3364
# Mathematics         3343
# English             3338
# Business            3327
# Art and Design      3323
# History             3321
# Sociology           3310
# Computer Science    3302
# Chemistry           3294
# Economics           3287
# Physics             3233
# Name: count, dtype: int64

# %%
df["ai_use_purpose"].value_counts()
# Out:
# ai_use_purpose
# note organization           2613
# writing feedback            2580
# quiz practice               2564
# plagiarism screening        2563
# content curation            2560
# exam revision               2533
# grading support             2527
# feedback drafting           2515
# creating exemplars          2510
# quiz generation             2502
# language translation        2502
# summarization               2474
# concept explanation         2473
# curriculum alignment        2467
# rubric design               2461
# coding help                 2451
# lesson planning             2449
# differentiation planning    2446
# proofreading                2419
# brainstorming               2391
# Name: count, dtype: int64

# %%
df["emotion_primary"].value_counts()
# Out:
# emotion_primary
# anticipation    11670
# neutral          6235
# surprise         5592
# trust            5567
# joy              5558
# optimism         5349
# fear             2558
# anxiety          2497
# anger            2488
# sadness          2486
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#           record_id  ai_use_frequency_per_week  session_count  \
# count  50000.000000               50000.000000   50000.000000
# mean   25000.500000                   2.032660      20.498980
# std    14433.901067                   1.277163       8.573265
# min        1.000000                   0.000000       1.000000
# 25%    12500.750000                   1.000000      14.000000
# 50%    25000.500000                   2.000000      20.000000
# 75%    37500.250000                   3.000000      27.000000
# max    50000.000000                   8.000000      51.000000
#
#        avg_session_duration_min  tasks_completed  hints_requested  \
# count              50000.000000     50000.000000     50000.000000
# mean                  15.562240        46.617040         6.154900
# std                    6.163321        19.842233         3.990166
# min                    3.000000         1.000000         0.000000
# 25%                   11.000000        33.000000         3.000000
# 50%                   16.000000        46.000000         6.000000
# 75%                   20.000000        60.000000         9.000000
# max                   41.000000       134.000000        24.000000
#
#        sentiment_polarity  subjectivity  pre_test_score  post_test_score  ...  \
# count        50000.000000  50000.000000    50000.000000     50000.000000  ...
# mean             0.202119      0.614831       68.404000        76.126520  ...
# std              0.494040      0.173278       14.047923        14.931484  ...
# min             -0.950000      0.200000        5.000000         4.000000  ...
# 25%             -0.060000      0.493000       59.000000        66.000000  ...
# 50%              0.269000      0.617000       68.000000        77.000000  ...
# 75%              0.611000      0.752000       78.000000        87.000000  ...
# max              0.950000      0.950000      100.000000       100.000000  ...
#
#        adaptive_difficulty_end  recommended_resources_count  \
# count              50000.00000                 50000.000000
# mean                   2.69912                     5.552640
# std                    1.02630                     3.062041
# min                    1.00000                     0.000000
# 25%                    2.00000                     3.000000
# 50%                    3.00000                     5.000000
# 75%                    3.00000                     8.000000
# max                    5.00000                    20.000000
#
#        perceived_usefulness  perceived_ease_of_use   trust_score  \
# count          50000.000000           50000.000000  50000.000000
# mean               3.543320               3.479000      3.384200
# std                1.056156               1.000289      1.012705
# min                1.000000               1.000000      1.000000
# 25%                3.000000               3.000000      3.000000
# 50%                4.000000               4.000000      3.000000
# 75%                4.000000               4.000000      4.000000
# max                5.000000               5.000000      5.000000
#
#        adoption_intention  satisfaction_score  ethical_concern_privacy  \
# count        50000.000000        50000.000000             50000.000000
# mean             3.457260            3.423600                 3.017140
# std              1.064235            1.071702                 1.053066
# min              1.000000            1.000000                 1.000000
# 25%              3.000000            3.000000                 2.000000
# 50%              4.000000            3.000000                 3.000000
# 75%              4.000000            4.000000                 4.000000
# max              5.000000            5.000000                 5.000000
#
#        ethical_concern_plagiarism  dropout_flag
# count                50000.000000  50000.000000
# mean                     3.122320      0.047260
# std                      1.049009      0.212197
# min                      1.000000      0.000000
# 25%                      2.000000      0.000000
# 50%                      3.000000      0.000000
# 75%                      4.000000      0.000000
# max                      5.000000      1.000000
#
# [8 rows x 22 columns]

# %%
import matplotlib.pyplot as plt

df["session_count"].hist(bins=20)

plt.title("Session Count Distribution")
plt.xlabel("Session Count")
plt.ylabel("Frequency")
plt.show()

# %%
plt.boxplot(df["session_count"])

plt.title("Session Count Boxplot")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12,8))

sns.heatmap(df.select_dtypes(include=['int64','float64']).corr(),
            annot=True,
            cmap="coolwarm")

plt.show()

# %%
df["trust_score"].hist()

plt.title("Trust Score Distribution")

plt.show()

# %%
plt.scatter(df["pre_test_score"],
            df["post_test_score"])

plt.xlabel("Pre Test Score")
plt.ylabel("Post Test Score")

plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))

plt.hist(df["session_count"], bins=20)

plt.title("Distribution of Session Count")
plt.xlabel("Session Count")
plt.ylabel("Frequency")

plt.show()

# %%
plt.figure(figsize=(8,5))

plt.boxplot(df["session_count"])

plt.title("Box Plot of Session Count")

plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))

plt.hist(df["session_count"], bins=20, edgecolor="black")

plt.title("Distribution of Session Count")
plt.xlabel("Session Count")
plt.ylabel("Frequency")

plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))

plt.boxplot(df["session_count"])

plt.title("Box Plot of Session Count")
plt.ylabel("Session Count")

plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12,8))

correlation = df.select_dtypes(include=['int64','float64']).corr()

sns.heatmap(correlation,
            annot=True,
            cmap="coolwarm",
            fmt=".2f")

plt.title("Correlation Heatmap")
plt.show()

# %%
import matplotlib.pyplot as plt

numerical_columns = [
    "session_count",
    "avg_session_duration_min",
    "pre_test_score",
    "post_test_score",
    "trust_score",
    "satisfaction_score"
]

df[numerical_columns].hist(figsize=(15,10), bins=20)

plt.suptitle("Distribution of Numerical Features")
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

pd.crosstab(df["role"], df["adoption_intention"]).plot(kind="bar", figsize=(8,5))

plt.title("Role vs Adoption Intention")
plt.xlabel("Role")
plt.ylabel("Count")
plt.legend(title="Adoption Intention")

plt.show()

# %%
df = df.drop(columns=["record_id", "user_id", "timestamp"])

df.head()
# Out:
#       role education_level      subject_area         ai_tool  \
# 0  student        graduate           Physics   LLM Assistant
# 1  student        graduate         Sociology  Concept Mapper
# 2  student   undergraduate         Chemistry        AI Tutor
# 3  student   undergraduate               Law  Quiz Generator
# 4  student   undergraduate  Computer Science        AI Tutor
#
#          ai_use_purpose  ai_use_frequency_per_week  session_count  \
# 0         summarization                          5             22
# 1         brainstorming                          3             27
# 2     note organization                          0             21
# 3  language translation                          3             26
# 4   concept explanation                          2             17
#
#    avg_session_duration_min  tasks_completed  hints_requested  ...  \
# 0                        18               63                4  ...
# 1                         8               85                8  ...
# 2                        10               82               15  ...
# 3                        19               53                6  ...
# 4                        26               50                8  ...
#
#   adaptive_difficulty_end recommended_resources_count  perceived_usefulness  \
# 0                       4                           8                     2
# 1                       1                           5                     1
# 2                       3                           4                     2
# 3                       4                           5                     2
# 4                       3                           9                     4
#
#    perceived_ease_of_use trust_score  adoption_intention  satisfaction_score  \
# 0                      3           3                   2                   2
# 1                      4           3                   2                   4
# 2                      2           3                   5                   3
# 3                      4           5                   4                   3
# 4                      2           4                   5                   4
#
#    ethical_concern_privacy  ethical_concern_plagiarism  dropout_flag
# 0                        3                           5             0
# 1                        2                           4             0
# 2                        3                           5             0
# 3                        2                           2             0
# 4                        2                           3             0
#
# [5 rows x 29 columns]

# %%
X = df.drop("adoption_intention", axis=1)

y = df["adoption_intention"]

# %%
print(X.shape)
print(y.shape)
# Out:
# (50000, 28)
# (50000,)

# %%
from sklearn.preprocessing import LabelEncoder

# Create LabelEncoder object
le = LabelEncoder()

# Select all categorical columns
categorical_columns = X.select_dtypes(include=['object']).columns

# Apply Label Encoding
for col in categorical_columns:
    X[col] = le.fit_transform(X[col])

print("Label Encoding Completed Successfully!")
# Out:
# Label Encoding Completed Successfully!

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 28 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   role                         50000 non-null  int64
#  1   education_level              50000 non-null  int64
#  2   subject_area                 50000 non-null  int64
#  3   ai_tool                      50000 non-null  int64
#  4   ai_use_purpose               50000 non-null  int64
#  5   ai_use_frequency_per_week    50000 non-null  int64
#  6   session_count                50000 non-null  int64
#  7   avg_session_duration_min     50000 non-null  int64
#  8   tasks_completed              50000 non-null  int64
#  9   hints_requested              50000 non-null  int64
#  10  text_feedback                50000 non-null  int64
#  11  sentiment_label              50000 non-null  int64
#  12  sentiment_polarity           50000 non-null  float64
#  13  subjectivity                 50000 non-null  float64
#  14  emotion_primary              50000 non-null  int64
#  15  pre_test_score               50000 non-null  int64
#  16  post_test_score              50000 non-null  int64
#  17  improvement                  50000 non-null  int64
#  18  adaptive_difficulty_start    50000 non-null  int64
#  19  adaptive_difficulty_end      50000 non-null  int64
#  20  recommended_resources_count  50000 non-null  int64
#  21  perceived_usefulness         50000 non-null  int64
#  22  perceived_ease_of_use        50000 non-null  int64
#  23  trust_score                  50000 non-null  int64
#  24  satisfaction_score           50000 non-null  int64
#  25  ethical_concern_privacy      50000 non-null  int64
#  26  ethical_concern_plagiarism   50000 non-null  int64
#  27  dropout_flag                 50000 non-null  int64
# dtypes: float64(2), int64(26)
# memory usage: 10.7 MB

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_scaled = scaler.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X_scaled,
    y,
    test_size=0.20,
    random_state=42
)

# %%
print("X_train :", X_train.shape)
print("X_test  :", X_test.shape)
print("y_train :", y_train.shape)
print("y_test  :", y_test.shape)
# Out:
# X_train : (40000, 28)
# X_test  : (10000, 28)
# y_train : (40000,)
# y_test  : (10000,)

# %%
print(df.shape)
# Out:
# (50000, 29)

# %%
print(X.shape)
print(y.shape)
# Out:
# (50000, 28)
# (50000,)

# %%
df = df.dropna()

# %%
df.head()
# Out:
#       role education_level      subject_area         ai_tool  \
# 0  student        graduate           Physics   LLM Assistant
# 1  student        graduate         Sociology  Concept Mapper
# 2  student   undergraduate         Chemistry        AI Tutor
# 3  student   undergraduate               Law  Quiz Generator
# 4  student   undergraduate  Computer Science        AI Tutor
#
#          ai_use_purpose  ai_use_frequency_per_week  session_count  \
# 0         summarization                          5             22
# 1         brainstorming                          3             27
# 2     note organization                          0             21
# 3  language translation                          3             26
# 4   concept explanation                          2             17
#
#    avg_session_duration_min  tasks_completed  hints_requested  ...  \
# 0                        18               63                4  ...
# 1                         8               85                8  ...
# 2                        10               82               15  ...
# 3                        19               53                6  ...
# 4                        26               50                8  ...
#
#   adaptive_difficulty_end recommended_resources_count  perceived_usefulness  \
# 0                       4                           8                     2
# 1                       1                           5                     1
# 2                       3                           4                     2
# 3                       4                           5                     2
# 4                       3                           9                     4
#
#    perceived_ease_of_use trust_score  adoption_intention  satisfaction_score  \
# 0                      3           3                   2                   2
# 1                      4           3                   2                   4
# 2                      2           3                   5                   3
# 3                      4           5                   4                   3
# 4                      2           4                   5                   4
#
#    ethical_concern_privacy  ethical_concern_plagiarism  dropout_flag
# 0                        3                           5             0
# 1                        2                           4             0
# 2                        3                           5             0
# 3                        2                           2             0
# 4                        2                           3             0
#
# [5 rows x 29 columns]

# %%
df.shape
# Out:
# (50000, 29)

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression(max_iter=1000, random_state=42)

lr.fit(X_train, y_train)

y_pred_lr = lr.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

print("Accuracy :", accuracy_score(y_test, y_pred_lr))

print("\nClassification Report\n")
print(classification_report(y_test, y_pred_lr))

print("\nConfusion Matrix\n")
print(confusion_matrix(y_test, y_pred_lr))
# Out:
# Accuracy : 0.4072
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00       387
#            2       0.37      0.12      0.18      1495
#            3       0.39      0.51      0.45      3047
#            4       0.42      0.72      0.53      3220
#            5       0.00      0.00      0.00      1851
#
#     accuracy                           0.41     10000
#    macro avg       0.24      0.27      0.23     10000
# weighted avg       0.31      0.41      0.33     10000
#
#
# Confusion Matrix
#
# [[   0   73  305    9    0]
#  [   0  178 1098  219    0]
#  [   0  164 1566 1317    0]
#  [   0   64  828 2328    0]
#  [   0    8  173 1670    0]]
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
import seaborn as sns
import matplotlib.pyplot as plt

cm = confusion_matrix(y_test, y_pred_lr)

plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")

plt.title("Logistic Regression Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")

plt.show()

# %%
from sklearn.naive_bayes import GaussianNB

nb = GaussianNB()

nb.fit(X_train, y_train)

y_pred_nb = nb.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

print("Accuracy :", accuracy_score(y_test, y_pred_nb))

print("\nClassification Report\n")
print(classification_report(y_test, y_pred_nb))

print("\nConfusion Matrix\n")
print(confusion_matrix(y_test, y_pred_nb))
# Out:
# Accuracy : 0.3103
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            1       0.14      0.46      0.22       387
#            2       0.31      0.26      0.28      1495
#            3       0.41      0.25      0.31      3047
#            4       0.40      0.08      0.14      3220
#            5       0.30      0.81      0.44      1851
#
#     accuracy                           0.31     10000
#    macro avg       0.31      0.37      0.28     10000
# weighted avg       0.36      0.31      0.27     10000
#
#
# Confusion Matrix
#
# [[ 179  124   69    6    9]
#  [ 468  389  398   56  184]
#  [ 447  475  771  185 1169]
#  [ 144  227  521  270 2058]
#  [  15   53  132  157 1494]]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

cm = confusion_matrix(y_test, y_pred_nb)

plt.figure(figsize=(6,5))

sns.heatmap(cm,
            annot=True,
            fmt="d",
            cmap="Greens")

plt.title("Naive Bayes Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")

plt.show()

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=5)

knn.fit(X_train, y_train)

y_pred_knn = knn.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

print("Accuracy :", accuracy_score(y_test, y_pred_knn))

print("\nClassification Report\n")
print(classification_report(y_test, y_pred_knn))

print("\nConfusion Matrix\n")
print(confusion_matrix(y_test, y_pred_knn))
# Out:
# Accuracy : 0.3346
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            1       0.14      0.10      0.11       387
#            2       0.31      0.32      0.31      1495
#            3       0.32      0.40      0.36      3047
#            4       0.39      0.40      0.40      3220
#            5       0.31      0.17      0.21      1851
#
#     accuracy                           0.33     10000
#    macro avg       0.29      0.28      0.28     10000
# weighted avg       0.33      0.33      0.33     10000
#
#
# Confusion Matrix
#
# [[  38  138  180   29    2]
#  [  75  479  657  249   35]
#  [ 106  555 1231  914  241]
#  [  47  294 1167 1291  421]
#  [   9   98  605  832  307]]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

cm = confusion_matrix(y_test, y_pred_knn)

plt.figure(figsize=(6,5))

sns.heatmap(cm, annot=True, fmt="d", cmap="Oranges")

plt.title("KNN Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")

plt.show()

# %%
from sklearn.tree import DecisionTreeClassifier

dt = DecisionTreeClassifier(random_state=42)

dt.fit(X_train, y_train)

y_pred_dt = dt.predict(X_test)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

cm = confusion_matrix(y_test, y_pred_dt)

plt.figure(figsize=(6,5))

sns.heatmap(cm,
            annot=True,
            fmt="d",
            cmap="Purples")

plt.title("Decision Tree Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")

plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(
    n_estimators=100,
    random_state=42
)

rf.fit(X_train, y_train)

y_pred_rf = rf.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

print("Accuracy :", accuracy_score(y_test, y_pred_rf))

print("\nClassification Report\n")
print(classification_report(y_test, y_pred_rf))

print("\nConfusion Matrix\n")
print(confusion_matrix(y_test, y_pred_rf))
# Out:
# Accuracy : 0.396
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00       387
#            2       0.36      0.21      0.27      1495
#            3       0.39      0.45      0.42      3047
#            4       0.42      0.65      0.51      3220
#            5       0.32      0.09      0.14      1851
#
#     accuracy                           0.40     10000
#    macro avg       0.30      0.28      0.27     10000
# weighted avg       0.37      0.40      0.36     10000
#
#
# Confusion Matrix
#
# [[   0  120  253   13    1]
#  [   0  321  914  239   21]
#  [   0  322 1370 1218  137]
#  [   0  105  810 2099  206]
#  [   0   18  190 1473  170]]
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_pred_rf)

plt.figure(figsize=(6,5))

sns.heatmap(cm,
            annot=True,
            fmt="d",
            cmap="Blues")

plt.title("Random Forest Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")

plt.show()

# %%
from sklearn.svm import SVC

svm = SVC(kernel='rbf', random_state=42)

svm.fit(X_train, y_train)

y_pred_svm = svm.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

print("Accuracy :", accuracy_score(y_test, y_pred_svm))

print("\nClassification Report\n")
print(classification_report(y_test, y_pred_svm))

print("\nConfusion Matrix\n")
print(confusion_matrix(y_test, y_pred_svm))
# Out:
# Accuracy : 0.4103
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00       387
#            2       0.42      0.13      0.20      1495
#            3       0.40      0.52      0.45      3047
#            4       0.42      0.72      0.53      3220
#            5       0.00      0.00      0.00      1851
#
#     accuracy                           0.41     10000
#    macro avg       0.25      0.27      0.24     10000
# weighted avg       0.32      0.41      0.34     10000
#
#
# Confusion Matrix
#
# [[   0   54  324    9    0]
#  [   0  192 1084  219    0]
#  [   0  148 1582 1315    2]
#  [   0   51  838 2329    2]
#  [   0    7  174 1670    0]]
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_pred_svm)

plt.figure(figsize=(6,5))

sns.heatmap(cm,
            annot=True,
            fmt="d",
            cmap="Reds")

plt.title("SVM Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")

plt.show()

# %%
model_names = [
    "Logistic Regression",
    "Naive Bayes",
    "KNN",
    "Decision Tree",
    "Random Forest",
    "SVM"
]

accuracies = [
    accuracy_score(y_test, y_pred_lr),
    accuracy_score(y_test, y_pred_nb),
    accuracy_score(y_test, y_pred_knn),
    accuracy_score(y_test, y_pred_dt),
    accuracy_score(y_test, y_pred_rf),
    accuracy_score(y_test, y_pred_svm)
]

import pandas as pd

comparison = pd.DataFrame({
    "Model": model_names,
    "Accuracy": accuracies
})

comparison
# Out:
#                  Model  Accuracy
# 0  Logistic Regression    0.4072
# 1          Naive Bayes    0.3103
# 2                  KNN    0.3346
# 3        Decision Tree    0.3089
# 4        Random Forest    0.3960
# 5                  SVM    0.4103

# %%
import matplotlib.pyplot as plt

comparison.sort_values("Accuracy").plot(
    x="Model",
    y="Accuracy",
    kind="bar",
    figsize=(10,5),
    legend=False
)

plt.title("Accuracy Comparison of Machine Learning Models")
plt.ylabel("Accuracy")
plt.xticks(rotation=20)

plt.show()

# %%
best_model = comparison.loc[comparison["Accuracy"].idxmax()]

print("Best Model:")
print(best_model)
# Out:
# Best Model:
# Model          SVM
# Accuracy    0.4103
# Name: 5, dtype: object

# %%
print("Best Model :", best_model["Model"])
print("Accuracy   :", round(best_model["Accuracy"] * 100, 2), "%")
# Out:
# Best Model : SVM
# Accuracy   : 41.03 %

# %%
import pandas as pd

feature_importance = pd.DataFrame({
    "Feature": X.columns,
    "Importance": rf.feature_importances_
})

feature_importance = feature_importance.sort_values(
    by="Importance",
    ascending=False
)

feature_importance.head(10)
# Out:
#                      Feature  Importance
# 12        sentiment_polarity    0.090445
# 13              subjectivity    0.061857
# 10             text_feedback    0.061850
# 8            tasks_completed    0.055844
# 6              session_count    0.050223
# 15            pre_test_score    0.048967
# 17               improvement    0.048821
# 7   avg_session_duration_min    0.047777
# 16           post_test_score    0.047658
# 4             ai_use_purpose    0.042332

# %%
import matplotlib.pyplot as plt

top_features = feature_importance.head(10)

plt.figure(figsize=(10,6))

plt.barh(top_features["Feature"], top_features["Importance"])

plt.title("Top 10 Important Features")
plt.xlabel("Importance Score")
plt.ylabel("Features")

plt.gca().invert_yaxis()

plt.show()

# %%
new_prediction = rf.predict(X_test[:5])

print("Predicted Values:")
print(new_prediction)

print("\nActual Values:")
print(y_test.iloc[:5].values)
# Out:
# Predicted Values:
# [3 4 2 3 3]
#
# Actual Values:
# [4 5 2 4 2]

# %%
import joblib

joblib.dump(rf, "best_model.pkl")

print("Model saved successfully!")
# Out:
# Model saved successfully!

# %%
loaded_model = joblib.load("best_model.pkl")

prediction = loaded_model.predict(X_test[:5])

print(prediction)
# Out:
# [3 4 2 3 3]

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(random_state=42)

param_grid = {
    'n_estimators': [100, 200],
    'max_depth': [10, 20, None],
    'min_samples_split': [2, 5],
    'min_samples_leaf': [1, 2]
}

grid_search = GridSearchCV(
    estimator=rf,
    param_grid=param_grid,
    cv=5,
    scoring='accuracy',
    n_jobs=-1
)

grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(random_state=42), n_jobs=-1,
#              param_grid={'max_depth': [10, 20, None],
#                          'min_samples_leaf': [1, 2],
#                          'min_samples_split': [2, 5],
#                          'n_estimators': [100, 200]},
#              scoring='accuracy')

# %%
print("Best Parameters:")
print(grid_search.best_params_)

print("\nBest Cross Validation Accuracy:")
print(grid_search.best_score_)
# Out:
# Best Parameters:
# {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 100}
#
# Best Cross Validation Accuracy:
# 0.41289999999999993

# %%
best_rf = grid_search.best_estimator_

y_pred_best = best_rf.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

print("Optimized Accuracy :", accuracy_score(y_test, y_pred_best))

print("\nClassification Report")
print(classification_report(y_test, y_pred_best))

print("\nConfusion Matrix")
print(confusion_matrix(y_test, y_pred_best))
# Out:
# Optimized Accuracy : 0.406
#
# Classification Report
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00       387
#            2       0.37      0.10      0.16      1495
#            3       0.39      0.52      0.45      3047
#            4       0.42      0.72      0.53      3220
#            5       0.25      0.00      0.00      1851
#
#     accuracy                           0.41     10000
#    macro avg       0.29      0.27      0.23     10000
# weighted avg       0.36      0.41      0.33     10000
#
#
# Confusion Matrix
# [[   0   58  320    9    0]
#  [   0  153 1122  220    0]
#  [   0  151 1579 1316    1]
#  [   0   47  844 2327    2]
#  [   0    6  175 1669    1]]
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
import seaborn as sns
import matplotlib.pyplot as plt

cm = confusion_matrix(y_test, y_pred_best)

plt.figure(figsize=(6,5))

sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Greens"
)

plt.title("Optimized Random Forest")
plt.xlabel("Predicted")
plt.ylabel("Actual")

plt.show()

# %%
from sklearn.model_selection import cross_val_score

scores = cross_val_score(
    best_rf,
    X_scaled,
    y,
    cv=5,
    scoring="accuracy"
)

print("Cross Validation Scores:")
print(scores)

print("\nAverage Accuracy:")
print(scores.mean())
# Out:
# Cross Validation Scores:
# [0.4147 0.4162 0.4101 0.4085 0.4081]
#
# Average Accuracy:
# 0.41152000000000005

# %%
from sklearn.metrics import precision_score, recall_score, f1_score
import pandas as pd

results = pd.DataFrame({
    "Model": [
        "Logistic Regression",
        "Naive Bayes",
        "KNN",
        "Decision Tree",
        "Random Forest",
        "SVM"
    ],
    "Accuracy": [
        accuracy_score(y_test, y_pred_lr),
        accuracy_score(y_test, y_pred_nb),
        accuracy_score(y_test, y_pred_knn),
        accuracy_score(y_test, y_pred_dt),
        accuracy_score(y_test, y_pred_rf),
        accuracy_score(y_test, y_pred_svm)
    ],
    "Precision": [
        precision_score(y_test, y_pred_lr, average="weighted"),
        precision_score(y_test, y_pred_nb, average="weighted"),
        precision_score(y_test, y_pred_knn, average="weighted"),
        precision_score(y_test, y_pred_dt, average="weighted"),
        precision_score(y_test, y_pred_rf, average="weighted"),
        precision_score(y_test, y_pred_svm, average="weighted")
    ],
    "Recall": [
        recall_score(y_test, y_pred_lr, average="weighted"),
        recall_score(y_test, y_pred_nb, average="weighted"),
        recall_score(y_test, y_pred_knn, average="weighted"),
        recall_score(y_test, y_pred_dt, average="weighted"),
        recall_score(y_test, y_pred_rf, average="weighted"),
        recall_score(y_test, y_pred_svm, average="weighted")
    ],
    "F1-Score": [
        f1_score(y_test, y_pred_lr, average="weighted"),
        f1_score(y_test, y_pred_nb, average="weighted"),
        f1_score(y_test, y_pred_knn, average="weighted"),
        f1_score(y_test, y_pred_dt, average="weighted"),
        f1_score(y_test, y_pred_rf, average="weighted"),
        f1_score(y_test, y_pred_svm, average="weighted")
    ]
})

results
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#                  Model  Accuracy  Precision  Recall  F1-Score
# 0  Logistic Regression    0.4072   0.310071  0.4072  0.333940
# 1          Naive Bayes    0.3103   0.360892  0.3103  0.272102
# 2                  KNN    0.3346   0.330700  0.3346  0.327191
# 3        Decision Tree    0.3089   0.309632  0.3089  0.309200
# 4        Random Forest    0.3960   0.365051  0.3960  0.357102
# 5                  SVM    0.4103   0.319272  0.4103  0.337432

# %%
import matplotlib.pyplot as plt

results.set_index("Model")[["Accuracy","Precision","Recall","F1-Score"]].plot(
    kind="bar",
    figsize=(12,6)
)

plt.title("Performance Comparison of Machine Learning Models")
plt.ylabel("Score")
plt.xticks(rotation=20)
plt.legend(loc="lower right")

plt.show()
